# %%
pip install cvlib
# Out:
# Collecting cvlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading cvlib-0.2.7.tar.gz (13.1 MB)
# Requirement already satisfied: numpy in c:\users\ayshwarya\anaconda3\lib\site-packages (from cvlib) (1.20.1)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: requests in c:\users\ayshwarya\anaconda3\lib\site-packages (from cvlib) (2.25.1)
# Requirement already satisfied: pillow in c:\users\ayshwarya\anaconda3\lib\site-packages (from cvlib) (9.0.1)
# Requirement already satisfied: imageio in c:\users\ayshwarya\anaconda3\lib\site-packages (from cvlib) (2.9.0)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ayshwarya\anaconda3\lib\site-packages (from requests->cvlib) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ayshwarya\anaconda3\lib\site-packages (from requests->cvlib) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ayshwarya\anaconda3\lib\site-packages (from requests->cvlib) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayshwarya\anaconda3\lib\site-packages (from requests->cvlib) (2020.12.5)
# Building wheels for collected packages: cvlib, imutils, progressbar
#   Building wheel for cvlib (setup.py): started
#   Building wheel for cvlib (setup.py): finished with status 'done'
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046371 sha256=b06a4b2fa1d1bdb434fe713d088b35a353b5ba76f46236709f8f82eb7b400424
#   Stored in directory: c:\users\ayshwarya\appdata\local\pip\cache\wheels\bb\11\55\82ced947752cc4056335a4ee9c304a93d43ce857230538f0ae
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25860 sha256=724f7dab7a59c94bedfbec75f5895e549dfb225e9643d910fc20efe28b9944a8
#   Stored in directory: c:\users\ayshwarya\appdata\local\pip\cache\wheels\59\1b\52\0dea905f8278d5514dc4d0be5e251967f8681670cadd3dca89
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12075 sha256=38f16ebb3d90e170b777d3a2a3b9dff47f2d4307fdc7a8603e514ce95930869e
#   Stored in directory: c:\users\ayshwarya\appdata\local\pip\cache\wheels\2c\67\ed\d84123843c937d7e7f5ba88a270d11036473144143355e2747
# Successfully built cvlib imutils progressbar
# Installing collected packages: progressbar, imutils, cvlib
# Successfully installed cvlib-0.2.7 imutils-0.5.4 progressbar-2.5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

image = cv2.imread("cars.jpg")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# Number of cars in this image are 5
